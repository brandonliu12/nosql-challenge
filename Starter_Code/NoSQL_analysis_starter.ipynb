# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['food']

# %%
# assign the collection to a variable
food = db['food']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
import pprint

# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}
field = {'BusinessName': 1, 'scores': 1, '_id': 0}
hygiene = db.food.find(query, field)
hygiene_list = []
# Iterate over the cursor and print each document
for document in hygiene:
    pprint.pprint(document)
    hygiene_list.append(document)
# Out:
# {'BusinessName': 'The Chase Rest Home',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Brenalwood',
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}
# {'BusinessName': 'Melrose Hotel',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Seaford Pizza',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'BusinessName': 'Golden Palace',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'BusinessName': "Ashby's Butchers",
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'South Sea Express Cuisine',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Golden Palace',
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}
# {'BusinessName': 'The Tulip Tree',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 5}}
# {'BusinessName': 'F & S',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Longhouse',
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 25}}
# {'BusinessName': 'Westview Playgroup Based At Downsview Comm Primary',
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Whatever The Weather Coffee',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}
# {'BusinessName': 'Kings Restaurant (Oriental)',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 25}}
# {'BusinessName': 'Xich Lo',
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 20, 'Structural': 5}}
# {'BusinessName': 'Asian Supermarket Ltd: T/A Best Food Wine Ltd',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Londis',
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 10}}
# {'BusinessName': 'Costcutter',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}
# {'BusinessName': 'La Simon Ltd',
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 20, 'Structural': 15}}
# {'BusinessName': 'Caribiscus Ltd',
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Kennedy Fried Chicken',
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Gah Shing',
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 20, 'Structural': 15}}
# {'BusinessName': 'A1 News & Wine',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'BusinessName': 'Cakes & Bakes',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}
# {'BusinessName': 'Sahajanand Catering Limited',
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Sisko Cafe',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Magazin Romanesc Diana',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'BusinessName': 'Bali Maamalas',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'BusinessName': 'Angels Bakery',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Nikkis Place Restaurant',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Chicago 30',
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}
# {'BusinessName': 'Samui Thai Restaurant',
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Pakhtoonkhwa Restaurant',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'New Happy Garden',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Mummy Yum',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': 'Gospodina',
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 20}}
# {'BusinessName': "Leo's Bar & Grill",
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 5}}
# {'BusinessName': 'Royal Ribs',
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}
# {'BusinessName': 'Great Hallingbury Manor Hotel',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'BusinessName': 'The Dog And Duck',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}
# {'BusinessName': 'Oriental Cottage',
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}

# %%
# Use count_documents to display the number of documents in the result
db.food.count_documents(query)
# Display the first document in the results using pprint
result = food.find_one(query)
pprint.pprint(result)
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6461011e1142c1728698b31f'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
import pandas as pd
# Convert the result to a Pandas DataFrame

result_df = pd.DataFrame(hygiene_list)

# %%
# Display the number of rows in the DataFrame
print(len(result_df))
# Out:
# 41

# %%
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
#                 BusinessName  \
# 0        The Chase Rest Home
# 1                 Brenalwood
# 2              Melrose Hotel
# 3              Seaford Pizza
# 4              Golden Palace
# 5           Ashby's Butchers
# 6  South Sea Express Cuisine
# 7              Golden Palace
# 8             The Tulip Tree
# 9                      F & S
#
#                                               scores
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'RatingValue': {'$gt': 3}}

# Use count_documents to display the number of documents in the result
count = food.count_documents(query)
print("Number of documents in London with RatingValue >= 4:", count)
limit = 1

# Display the first document in the results using pprint
result = food.find(query).sort(sort).limit(limit)
for document in result:
    pprint.pprint(document)
# Out:
# Number of documents in London with RatingValue >= 4: 31257
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6461011e1142c172869897e2'),
#  'geocode': {'latitude': Decimal128('51.086058'),
#              'longitude': Decimal128('1.196408')},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %%
# Convert the result to a Pandas DataFrame
result = food.find(query).sort(sort)
result_dict = []
for document in result:
    result_dict.append(document)
result_df = pd.DataFrame(result_dict)

# Display the number of rows in the DataFrame
print(len(result_df))

# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# 31257
#                         _id   FHRSID  ChangesByServerID  \
# 0  6461011e1142c172869897e2   647177                  0
# 1  6461011e1142c172869897eb   987206                  0
# 2  6461011e1142c172869897f9   805702                  0
# 3  6461011e1142c172869897fb  1396944                  0
# 4  6461011e1142c17286989808  1058636                  0
# 5  6461011e1142c1728698980a   865873                  0
# 6  6461011e1142c1728698980b  1138444                  0
# 7  6461011e1142c17286989837   505847                  0
# 8  6461011e1142c17286989839  1241756                  0
# 9  6461011e1142c1728698983b   703619                  0
#
#   LocalAuthorityBusinessID                BusinessName  \
# 0             PI/000041489         Wear Bay Bowls Club
# 1             PI/000075655            The Ships Galley
# 2             PI/000073219    Dr Legumes - Harbour Arm
# 3             PI/000078122                      Dino's
# 4             PI/000076450                      Babaji
# 5             PI/000074303  Sole Kitchen - Harbour Arm
# 6             PI/000077128                Lucky Radish
# 7             PI/000038692               The Guildhall
# 8             PI/000077659                Tips Wok Box
# 9             PI/000054068                     Jolsons
#
#               BusinessType  BusinessTypeID                    AddressLine1  \
# 0        Pub/bar/nightclub            7843                   Wear Bay Road
# 1        Pub/bar/nightclub            7843                        The Ship
# 2  Restaurant/Cafe/Canteen               1              Folkestone Harbour
# 3  Restaurant/Cafe/Canteen               1              Folkestone Harbour
# 4   Takeaway/sandwich shop            7844              Folkestone Harbour
# 5   Takeaway/sandwich shop            7844              Folkestone Harbour
# 6           Mobile caterer            7846              Folkestone Harbour
# 7        Pub/bar/nightclub            7843                    42 The Bayle
# 8   Takeaway/sandwich shop            7844  Ground Floor Business Premises
# 9        Pub/bar/nightclub            7843              2-6 Tontine Street
#
#             AddressLine2 AddressLine3  ...  \
# 0             Folkestone         Kent  ...
# 1           23 The Stade   Folkestone  ...
# 2  Harbour Approach Road   Folkestone  ...
# 3  Harbour Approach Road   Folkestone  ...
# 4  Harbour Approach Road   Folkestone  ...
# 5  Harbour Approach Road   Folkestone  ...
# 6  Harbour Approach Road   Folkestone  ...
# 7             Folkestone         Kent  ...
# 8       4 Tontine Street   Folkestone  ...
# 9             Folkestone         Kent  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...       FHRS
# 3  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
# 4  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 5  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...       FHRS
# 6  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 7  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...       FHRS
# 8  {'Hygiene': 10, 'Structural': 0, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
#
#                                              geocode  RightToReply  \
# 0     {'longitude': 1.196408, 'latitude': 51.086058}
# 1      {'longitude': 1.188537, 'latitude': 51.08084}
# 2  {'longitude': 1.18590330311705, 'latitude': 51...
# 3  {'longitude': 1.18590330311705, 'latitude': 51...
# 4  {'longitude': 1.18590330311705, 'latitude': 51...
# 5  {'longitude': 1.18590330311705, 'latitude': 51...
# 6  {'longitude': 1.18590330311705, 'latitude': 51...
# 7     {'longitude': 1.182962, 'latitude': 51.079301}
# 8  {'longitude': 1.18431901931763, 'latitude': 51...
# 9      {'longitude': 1.18429, 'latitude': 51.080956}
#
#       Distance NewRatingPending  \
# 0  4591.821311            False
# 1  4591.912145            False
# 2  4591.914705            False
# 3  4591.914705            False
# 4  4591.914705            False
# 5  4591.914705            False
# 6  4591.914705            False
# 7  4592.057518            False
# 8  4592.069893            False
# 9  4592.071255            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links longitude latitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 1  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 2  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 3  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 4  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 5  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 6  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 7  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 8  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 9  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.1
latitude = 51.0481524
longitude = 1.113563

query = {
    'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search},
    'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search},
    'RatingValue': 5
}

sort = [('scores.Hygiene', -1)]
limit = 5

# Retrieve the matching documents and sort by hygiene score
results = food.find(query).sort(sort).limit(limit)
results_dict = []

# Iterate over the results and print each document
for document in results:
    pprint.pprint(document)
    results_dict.append(document)
# Out:
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Pick Up Pintxos',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1043701,
#  'LocalAuthorityBusinessID': 'PI/000076360',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2018-04-18T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6461011e1142c172869897f1'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043701',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6461011e1142c172869897e3'),
#  'geocode': {'latitude': Decimal128('51.083812'),
#              'longitude': Decimal128('1.195625')},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Lobster & Burger',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1495230,
#  'LocalAuthorityBusinessID': 'PI/000078175',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2022-04-05T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6461011e1142c172869897f8'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1495230',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'That Burger - Harbour Arm',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 805703,
#  'LocalAuthorityBusinessID': 'PI/000073221',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2018-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6461011e1142c172869897f4'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/805703',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '23 The Stade',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Ship',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.912144538092,
#  'FHRSID': 289352,
#  'LocalAuthorityBusinessID': 'PI/000002460',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6AB',
#  'RatingDate': '2015-08-27T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6461011e1142c172869897e8'),
#  'geocode': {'latitude': Decimal128('51.08084'),
#              'longitude': Decimal128('1.188537')},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289352',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# Convert result to Pandas DataFrame
result_df = pd.DataFrame(results_dict)
result_df.head()
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6461011e1142c172869897f1  1043701                  0
# 1  6461011e1142c172869897e3  1043695                  0
# 2  6461011e1142c172869897f8  1495230                  0
# 3  6461011e1142c172869897f4   805703                  0
# 4  6461011e1142c172869897e8   289352                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0             PI/000076360            Pick Up Pintxos
# 1             PI/000073616               The Pavilion
# 2             PI/000078175           Lobster & Burger
# 3             PI/000073221  That Burger - Harbour Arm
# 4             PI/000002460                   The Ship
#
#               BusinessType  BusinessTypeID         AddressLine1  \
# 0   Takeaway/sandwich shop            7844   Folkestone Harbour
# 1  Restaurant/Cafe/Canteen               1  East Cliff Pavilion
# 2   Takeaway/sandwich shop            7844   Folkestone Harbour
# 3   Takeaway/sandwich shop            7844   Folkestone Harbour
# 4        Pub/bar/nightclub            7843         23 The Stade
#
#             AddressLine2 AddressLine3  ...  \
# 0  Harbour Approach Road   Folkestone  ...
# 1          Wear Bay Road   Folkestone  ...
# 2  Harbour Approach Road   Folkestone  ...
# 3  Harbour Approach Road   Folkestone  ...
# 4             Folkestone         Kent  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
#
#                                              geocode  RightToReply  \
# 0  {'longitude': 1.18590330311705, 'latitude': 51...
# 1     {'longitude': 1.195625, 'latitude': 51.083812}
# 2  {'longitude': 1.18590330311705, 'latitude': 51...
# 3  {'longitude': 1.18590330311705, 'latitude': 51...
# 4      {'longitude': 1.188537, 'latitude': 51.08084}
#
#       Distance NewRatingPending  \
# 0  4591.914705            False
# 1  4591.765489            False
# 2  4591.914705            False
# 3  4591.914705            False
# 4  4591.912145            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links longitude latitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 1  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 2  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 3  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 4  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
#
# [5 rows x 30 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

match_query = {'$match': {'scores.Hygiene': 0}}
group_query = {'$group': {'_id': '$LocalAuthorityName', 'count': {'$sum': 1}}}
sort = {'$sort': {'count': -1}}

# Combine the pipeline stages
pipeline = [match_query, group_query, sort]

# Execute the pipeline
results = list(food.aggregate(pipeline))

# Print the number of documents in the result
print("Number of documents:", len(results))

# Print the first 10 results
pprint.pprint(results[:10])
# Out:
# Number of documents: 55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
result_dict = []
for document in results:
    results_dict.append(document)
result_df = pd.DataFrame(results_dict)
# Display the number of rows in the DataFrame
print(len(result_df))
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# 115
#                         _id     FHRSID  ChangesByServerID  \
# 0  6461011e1142c172869897f1  1043701.0                0.0
# 1  6461011e1142c172869897e3  1043695.0                0.0
# 2  6461011e1142c172869897f8  1495230.0                0.0
# 3  6461011e1142c172869897f4   805703.0                0.0
# 4  6461011e1142c172869897e8   289352.0                0.0
# 5                    Thanet        NaN                NaN
# 6                 Greenwich        NaN                NaN
# 7                 Maidstone        NaN                NaN
# 8                    Newham        NaN                NaN
# 9                     Swale        NaN                NaN
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0             PI/000076360            Pick Up Pintxos
# 1             PI/000073616               The Pavilion
# 2             PI/000078175           Lobster & Burger
# 3             PI/000073221  That Burger - Harbour Arm
# 4             PI/000002460                   The Ship
# 5                      NaN                        NaN
# 6                      NaN                        NaN
# 7                      NaN                        NaN
# 8                      NaN                        NaN
# 9                      NaN                        NaN
#
#               BusinessType  BusinessTypeID         AddressLine1  \
# 0   Takeaway/sandwich shop          7844.0   Folkestone Harbour
# 1  Restaurant/Cafe/Canteen             1.0  East Cliff Pavilion
# 2   Takeaway/sandwich shop          7844.0   Folkestone Harbour
# 3   Takeaway/sandwich shop          7844.0   Folkestone Harbour
# 4        Pub/bar/nightclub          7843.0         23 The Stade
# 5                      NaN             NaN                  NaN
# 6                      NaN             NaN                  NaN
# 7                      NaN             NaN                  NaN
# 8                      NaN             NaN                  NaN
# 9                      NaN             NaN                  NaN
#
#             AddressLine2 AddressLine3  ... SchemeType  \
# 0  Harbour Approach Road   Folkestone  ...       FHRS
# 1          Wear Bay Road   Folkestone  ...       FHRS
# 2  Harbour Approach Road   Folkestone  ...       FHRS
# 3  Harbour Approach Road   Folkestone  ...       FHRS
# 4             Folkestone         Kent  ...       FHRS
# 5                    NaN          NaN  ...        NaN
# 6                    NaN          NaN  ...        NaN
# 7                    NaN          NaN  ...        NaN
# 8                    NaN          NaN  ...        NaN
# 9                    NaN          NaN  ...        NaN
#
#                                              geocode RightToReply  \
# 0  {'longitude': 1.18590330311705, 'latitude': 51...
# 1     {'longitude': 1.195625, 'latitude': 51.083812}
# 2  {'longitude': 1.18590330311705, 'latitude': 51...
# 3  {'longitude': 1.18590330311705, 'latitude': 51...
# 4      {'longitude': 1.188537, 'latitude': 51.08084}
# 5                                                NaN          NaN
# 6                                                NaN          NaN
# 7                                                NaN          NaN
# 8                                                NaN          NaN
# 9                                                NaN          NaN
#
#       Distance NewRatingPending  \
# 0  4591.914705            False
# 1  4591.765489            False
# 2  4591.914705            False
# 3  4591.914705            False
# 4  4591.912145            False
# 5          NaN              NaN
# 6          NaN              NaN
# 7          NaN              NaN
# 8          NaN              NaN
# 9          NaN              NaN
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                                links longitude latitude  \
# 0  [{'rel': 'self', 'href': 'https://api.ratings....       NaN      NaN
# 1  [{'rel': 'self', 'href': 'https://api.ratings....       NaN      NaN
# 2  [{'rel': 'self', 'href': 'https://api.ratings....       NaN      NaN
# 3  [{'rel': 'self', 'href': 'https://api.ratings....       NaN      NaN
# 4  [{'rel': 'self', 'href': 'https://api.ratings....       NaN      NaN
# 5                                                NaN       NaN      NaN
# 6                                                NaN       NaN      NaN
# 7                                                NaN       NaN      NaN
# 8                                                NaN       NaN      NaN
# 9                                                NaN       NaN      NaN
#
#     count
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5  1130.0
# 6   882.0
# 7   713.0
# 8   711.0
# 9   686.0
#
# [10 rows x 31 columns]
